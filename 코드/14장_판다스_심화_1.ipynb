# %% [markdown]
# ## Chapter 14. 판다스 심화 1

# %% [markdown]
# ### 14.1. 알아두면 유용한 판다스 함수들

# %% [markdown]
# #### 14.1.1. 열 이름 일괄적으로 변경하기(add_prefix, add_suffix)

# %%
# 코드 14-1. 실습 예제 코드
import pandas as pd
data = [[1, 1, 8], [6, 9, 8], [2, 8, 7], [6, 9, 1]]
df = pd.DataFrame(data, columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  1  1  8
# 1  6  9  8
# 2  2  8  7
# 3  6  9  1

# %%
# 코드 14-2. add_prefix 함수와 add_suffix 함수 실습
# 열 이름에 접두사 'Col' 추가
df.add_prefix('Col')

# 열 이름에 접미사 '_column' 추가
df.add_suffix('_column')
# Out:
#    A_column  B_column  C_column
# 0         1         1         8
# 1         6         9         8
# 2         2         8         7
# 3         6         9         1

# %% [markdown]
# #### 14.1.2. 열의 데이터를 반환한 뒤 삭제하기(pop)

# %%
# 코드 14-3. pop 함수 실습
df1 = df.copy() # 코드 14-1의 df를 복제한 df1 준비
df1['B + C'] = df1.pop('B') + df1.pop('C')
df1
# Out:
#    A  B + C
# 0  1      9
# 1  6     17
# 2  2     15
# 3  6     10

# %% [markdown]
# #### 14.1.3. 특정 위치에 열 생성하기(insert)

# %%
# 코드 14-4. insert 함수 실습
df1 = df.copy() # 코드 14-1의 df를 복제한 df1 준비

# 모든 열의 합을 맨 왼쪽에 total 열로 생성
df1.insert(0, 'total', df1.sum(axis=1))
df1
# Out:
#    total  A  B  C
# 0     10  1  1  8
# 1     23  6  9  8
# 2     17  2  8  7
# 3     16  6  9  1

# %%
# 코드 14-5. insert 함수와 pop 함수를 조합해 C 열을 맨 왼쪽으로 이동
df1.insert(0, 'C', df1.pop('C'))
df1
# Out:
#    C  total  A  B
# 0  8     10  1  1
# 1  8     23  6  9
# 2  7     17  2  8
# 3  1     16  6  9

# %% [markdown]
# #### 14.1.4. 열 생성하기(assign)

# %%
# 코드 14-6. assign 함수로 개수와 합을 열로 생성하기
df.assign(count_val=3, total=df.sum(axis=1))
# Out:
#    A  B  C  count_val  total
# 0  1  1  8          3     10
# 1  6  9  8          3     23
# 2  2  8  7          3     17
# 3  6  9  1          3     16

# %%
# 코드 14-7. 함수 적용 후 assign 함수를 사용할 때는 인수로 lambda 함수를 입력
df.mul(2).assign(total=lambda x: x.sum(axis=1))
# Out:
#     A   B   C  total
# 0   2   2  16     20
# 1  12  18  16     46
# 2   4  16  14     34
# 3  12  18   2     32

# %% [markdown]
# #### 14.1.5. 쿼리문으로 필터링하기(query)

# %%
# 코드 14-8. query 함수 실습 예제 코드
data = {'국어': [92, 88, 93, 95, 72],
        '영어': [82, 73, 62, 99, 92],
        '총 점': [174, 161, 155, 194, 164]}
idx = ['김판다', '강승주', '조민영', '최진환', '박연준']
df = pd.DataFrame(data, index=idx)
df
# Out:
#      국어  영어  총 점
# 김판다  92  82  174
# 강승주  88  73  161
# 조민영  93  62  155
# 최진환  95  99  194
# 박연준  72  92  164

# %%
# 코드 14-9. 국어가 90점보다 높은 데이터 필터링
df.query('국어 > 90')
# Out:
#      국어  영어  총 점
# 김판다  92  82  174
# 조민영  93  62  155
# 최진환  95  99  194

# %%
# 코드 14-10. 외부 변수 n으로 국어가 90점보다 높은 데이터 필터링
n = 90
df.query('국어 > @n')
# Out:
#      국어  영어  총 점
# 김판다  92  82  174
# 조민영  93  62  155
# 최진환  95  99  194

# %%
# 코드 14-11. 영어에 10점을 더한 값보다 국어가 높은 데이터 필터링
df.query('국어 > 영어 + 10')
# Out:
#      국어  영어  총 점
# 강승주  88  73  161
# 조민영  93  62  155

# %%
# 코드 14-12. 국어가 80보다 크고 영어가 80보다 큰 데이터 필터링
df.query('(국어 > 80) & (영어 > 80)')
# Out:
#      국어  영어  총 점
# 김판다  92  82  174
# 최진환  95  99  194

# %%
# 코드 14-13. 열 이름에 공백이 존재하면 백틱(`) 기호를 활용
df.query('`총 점` > 170')
# Out:
#      국어  영어  총 점
# 김판다  92  82  174
# 최진환  95  99  194

# %%
# 코드 14-14. 인덱스는 index로 지정, 문자열은 다른 종류의 따옴표를 사용
df.query('index == "강승주"')
# Out:
#      국어  영어  총 점
# 강승주  88  73  161

# %% [markdown]
# #### 14.1.6. 행이나 열의 로케이션 반환하기(get_loc)

# %%
# 코드 14-15. get_loc 함수로 조민영 행의 로케이션 반환하기
df.index.get_loc('조민영')
# Out:
# 2

# %% [markdown]
# #### 14.1.7. 인덱스 클래스를 데이터 프레임이나 시리즈로 변환하기(to_frame, to_series)

# %%
# 코드 14-16. 인덱스 클래스를 데이터 프레임이나 시리즈로 변환하기
# 인덱스를 데이터 프레임으로 변환하기
df.index.to_frame()

# 인덱스를 시리즈로 변환하기
df.index.to_series()
# Out:
# 김판다    김판다
# 강승주    강승주
# 조민영    조민영
# 최진환    최진환
# 박연준    박연준
# dtype: object

# %% [markdown]
# #### 14.1.8. 데이터 프레임 연결하기(join)

# %%
# 코드 14-17. join 함수로 데이터 프레임 연결하기
data1 = {'국어_등수': [3, 4, 2, 1, 5], '영어_등수': [3, 4, 5, 1, 2]}
df1 = pd.DataFrame(data1, index=df.index)

# concat 함수로 연결하기(axis=1)
pd.concat([df, df1], axis=1)

# join 함수로 연결하기
df.join(df1)
# Out:
#      국어  영어  총 점  국어_등수  영어_등수
# 김판다  92  82  174      3      3
# 강승주  88  73  161      4      4
# 조민영  93  62  155      2      5
# 최진환  95  99  194      1      1
# 박연준  72  92  164      5      2

# %% [markdown]
# #### 14.1.9. 연속적인 메서드 사용하기(pipe)

# %%
# 코드 14-18. pipe 함수로 print 함수 적용하기

# print 함수를 함수 형태로 적용하기
print(df.join(df1))

# pipe 함수에 print 함수를 인수로 입력해 연속 메서드 형태로 적용하기
df.join(df1).pipe(print)
# Out:
#      국어  영어  총 점  국어_등수  영어_등수
# 김판다  92  82  174      3      3
# 강승주  88  73  161      4      4
# 조민영  93  62  155      2      5
# 최진환  95  99  194      1      1
# 박연준  72  92  164      5      2
#      국어  영어  총 점  국어_등수  영어_등수
# 김판다  92  82  174      3      3
# 강승주  88  73  161      4      4
# 조민영  93  62  155      2      5
# 최진환  95  99  194      1      1
# 박연준  72  92  164      5      2

# %%
# 코드 14-19. pipe 함수에 lambda 함수 적용하기

# 함수 적용 결과를 변수 df2로 지정하고 영어 점수에서 국어 점수를 빼기
df2 = df.sort_values('총 점')
df2['영어'] - df2['국어']

# 위 작업을 변수 지정 없이 pipe 함수로 연속 메서드로 수행하기
df.sort_values('총 점').pipe(lambda x: x['영어'] - x['국어'])
# Out:
# 조민영   -31
# 강승주   -15
# 박연준    20
# 김판다   -10
# 최진환     4
# dtype: int64

# %% [markdown]
# #### 14.1.10. 범주형 데이터 인코딩하기(factorize)

# %%
# 코드 14-20. 범주형 데이터 인코딩하기
import pandas as pd

# 실습에 쓰일 시리즈 생성
s = pd.Series(['바나나', '사과', '바나나', '바나나', '귤'])

# 범주형 데이터 인코딩하기
code, uniq = pd.factorize(s)

# 인코딩 결과인 변수 code를 사용해 시리즈 생성하기
s1 = pd.Series(code, index=s.index)
s1
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    2
# dtype: int64

# %%
# 코드 14-21. 인코딩 결과인 s1으로 범주형 데이터 복원하기
uniq[s1]
# Out:
# Index(['바나나', '사과', '바나나', '바나나', '귤'], dtype='object')

# %% [markdown]
# #### 14.1.11. 원 핫 인코딩 수행하기(get_dummies)

# %%
# 코드 14-22. get_dummies 함수로 원 핫 인코딩 수행하기
pd.get_dummies(s)
# Out:
#        귤    바나나     사과
# 0  False   True  False
# 1  False  False   True
# 2  False   True  False
# 3  False   True  False
# 4   True  False  False

# %% [markdown]
# #### 14.1.12. 문자열 시리즈의 원 핫 인코딩 수행하기(str.get_dummies)

# %%
# 코드 14-23. 문자열 시리즈의 원 핫 인코딩(str.get_mummies)
import pandas as pd

# 실습에 쓰일 데이터 프레임 생성
data = {'수강완료': ['판다스A', '판다스B', '판다스C'],
        '이름': ['김판다/강승주', '김판다/조민영', '강승주']}

df = pd.DataFrame(data)

# 문자열 시리즈를 구분자(/)로 분리해 원 핫 인코딩
df['이름'].str.get_dummies('/')
# Out:
#    강승주  김판다  조민영
# 0    1    1    0
# 1    0    1    1
# 2    1    0    0

# %% [markdown]
# #### 14.1.13. 셀의 리스트를 행으로 전개하기(explode)

# %%
# 코드 14-24. 셀의 리스트를 행으로 전개하기
df1 = df.copy() # 코드 14-23의 df를 복제한 df1 준비

# 이름 열의 문자열을 구분자로 분리해 리스트로 생성
df1['이름'] = df1['이름'].str.split('/')

# df1의 이름 열의 리스트를 행으로 분리하기
df1.explode('이름')
# Out:
#    수강완료   이름
# 0  판다스A  김판다
# 0  판다스A  강승주
# 1  판다스B  김판다
# 1  판다스B  조민영
# 2  판다스C  강승주

# %%
# 코드 14-25. 코드 14-24를 원본을 변경하지 않는 assign 함수로 수행하기
df.assign(이름=df['이름'].str.split('/')).explode('이름')
# Out:
#    수강완료   이름
# 0  판다스A  김판다
# 0  판다스A  강승주
# 1  판다스B  김판다
# 1  판다스B  조민영
# 2  판다스C  강승주

# %% [markdown]
# #### 14.1.14. 복수 열을 기준으로 인코딩하기(ngroup)

# %%
# 코드 14-26. 복수 열의 데이터를 기준으로 인코딩하기
# 실습에 쓰일 데이터 프레임 생성
import pandas as pd
data = {'제품': ['새우깡', '양파링', '새우깡', '새우깡', '자갈치'],
        '할인': [True, False, False, True, True],
        '판매량': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# 제품 열과 할인 열을 그룹화해서 인코딩 수행
df.groupby(['제품', '할인'], sort=False).ngroup()
# Out:
# 0    0
# 1    1
# 2    2
# 3    0
# 4    3
# dtype: int64

# %% [markdown]
# #### 14.1.15. 데이터 프레임이나 시리즈가 완전히 동일한지 확인하기(equals)

# %%
# 코드 14-27. 두 시리즈가 완전히 동일한지 확인하기
import pandas as pd

# 동일한 데이터로 s1과 s2 생성하기
data = [1, 2, 3, float('nan')]
s1 = pd.Series(data)
s2 = pd.Series(data)

# 동등 비교 연산(==)으로는 확인할 수 없다.(NaN == NaN 은 False)
print((s1 == s2).all())

# equals 함수로 확인하는 것이 편리하다
s1.equals(s2)
# Out:
# False
# True

# %% [markdown]
# #### 14.1.16. 두 객체의 서로 다른 부분 반환하기(compare)

# %%
# 코드 14-28. compare 함수 실습 예제 코드
# 실습에 쓰일 데이터 프레임 생성
import pandas as pd
data1 = {'국어': {'A': 83, 'B': 73, 'C': 69, 'D': 79},
         '영어': {'A': 0, 'B': 96, 'C': 82, 'D': 70}}
data2 = {'국어': {'A': 83, 'B': 73, 'C': 69, 'D': 79},
         '영어': {'A': 100, 'B': 96, 'C': 82, 'D': 70}}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# df1과 df2가 동일한지 확인
df1.equals(df2)
# Out:
# False

# %%
# 코드 14-29. df1과 df2가 어떤 부분에서 차이가 있는지 확인
df1.compare(df2)
# Out:
#     영어
#   self  other
# A  0.0  100.0

# %% [markdown]
# #### 14.1.17. 가로 형식 데이터 프레임을 세로 형식으로 변환하기(wide_to_long)

# %%
# 코드 14-30. wide_to_long 함수 실습하기
# 실습에 쓰일 데이터 프레임 생성
import pandas as pd
data = {'이름': ['김판다', '강승주', '조민영'],
        '가형_국어': [60, 69, 83], '나형_국어': [63, 79, 66],
        '가형_영어': [63, 81, 84], '나형_영어': [99, 96, 84]}
df = pd.DataFrame(data)

# 가로 형식(wide) 데이터 프레임을 세로 형식(long)으로 변환
pd.wide_to_long(
    df, stubnames=['가형', '나형'], i='이름', j='과목', sep='_', suffix=r'.+'
)
# Out:
#         가형  나형
# 이름  과목
# 김판다 국어  60  63
# 강승주 국어  69  79
# 조민영 국어  83  66
# 김판다 영어  63  99
# 강승주 영어  81  96
# 조민영 영어  84  84

# %% [markdown]
# #### 14.1.18. HTML 테이블에서 데이터 프레임 불러오기(read_html)

# %% [markdown]
# 메이저 리그 2024년 타격 성적
#
# : 'https://www.baseball-reference.com/leagues/majors/2024-standard-batting.shtml

# %%
# 코드 14-31. HTML 테이블에서 데이터 프레임 불러오기
import pandas as pd
pd.options.display.max_rows = 6 # 6행까지만 출력
pd.options.display.max_columns = 10 # 10열까지만 출력

url1 = 'https://www.baseball-reference.com/leagues/majors/' \
'2024-standard-batting.shtml'

# 페이지의 모든 HTML 테이블을 dfs에 리스트로 담기
dfs = pd.read_html(url1)

# dfs에서 팀 순위 테이블 인덱싱
dfs[0]
# Out:
#                       Tm  #Bat  BatAge   R/G     G  ...  HBP   SH   SF  IBB  \
# 0   Arizona Diamondbacks    41    28.9  4.68    68  ...   31    7   25    4
# 1         Atlanta Braves    42    28.7  4.32    65  ...   27    0   17    4
# 2      Baltimore Orioles    40    27.1  5.13    67  ...   29    3   18    7
# ..                   ...   ...     ...   ...   ...  ...  ...  ...  ...  ...
# 30        League Average    39    28.2  4.33    68  ...   29    7   18    7
# 31                    Tm  #Bat  BatAge   R/G     G  ...  HBP   SH   SF  IBB
# 32                   NaN  1171    28.2  4.33  2038  ...  859  196  549  206
#
#       LOB
# 0     465
# 1     441
# 2     425
# ..    ...
# 30    454
# 31    LOB
# 32  13626
#
# [33 rows x 29 columns]

# %% [markdown]
# ### 14.2. 알아두면 유용한 넘파이 함수들

# %% [markdown]
# #### 14.2.1. 넘파이의 난수 생성 함수

# %%
# 코드 14-32. 넘파이의 random 함수를 활용해 데이터 프레임 생성하기
import pandas as pd
import numpy as np

np.random.seed(0) # 난수 고정
data = {'반': np.random.choice(['A', 'B'], size=5, p=[0.6, 0.4]),
        '국어': np.random.randint(60, 100, 5),
        '영어': np.random.randint(30, 70, 5)}
df = pd.DataFrame(data)
df
# Out:
#    반  국어  영어
# 0  A  81  54
# 1  B  96  42
# 2  B  83  31
# 3  A  66  68
# 4  A  84  69

# %% [markdown]
# #### 14.2.2. 두 배열 중 큰 값 반환하기(np.fmax)

# %%
# 코드 14-33. 영어에 가산점 30을 주고 국어 점수와 비교해 높은 점수 반환
np.fmax(df['국어'], df['영어'] + 30)
# Out:
# 0    84
# 1    96
# 2    83
# 3    98
# 4    99
# dtype: int64

# %% [markdown]
# #### 14.2.3. 각 행이나 각 열을 개별적으로 정렬하기(np.sort)

# %%
# 코드 14-34. np.sort 함수로 각 행을 개별적으로 정렬하기
# 실습에 쓰일 데이터 프레임 생성
np.random.seed(1) # 난수 고정
df1 = pd.DataFrame(np.random.randint(60, 100, (5, 4)))
print(df1) # 변수 df1 출력

# np.sort 함수로 정렬하고 결과(어레이)를 df1에 배정
df1[:] = np.sort(df1, axis=1)
df1
# Out:
#     0   1   2   3
# 0  97  72  68  69
# 1  71  65  75  60
# 2  76  61  72  67
# 3  66  85  80  97
# 4  78  80  71  88
#     0   1   2   3
# 0  68  69  72  97
# 1  60  65  71  75
# 2  61  67  72  76
# 3  66  80  85  97
# 4  71  78  80  88

# %% [markdown]
# ### 14.3. 인덱스 클래스

# %% [markdown]
# #### 14.3.1. 인덱스 클래스 생성하기

# %%
# 코드 14-35. 인덱스 클래스 생성하기
import pandas as pd
pd.Index(['A', 'B', 'C'])
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# 코드 14-36. 2부터 7까지의 RangeIndex 생성하기
pd.RangeIndex(2, 8)
# Out:
# RangeIndex(start=2, stop=8, step=1)

# %% [markdown]
# #### 14.3.2. 인덱스 클래스에 적용하는 함수들

# %%
# 코드 14-37. 인덱스 클래스에 적용하는 함수 실습 예제 코드
idx1 = pd.Index(['A', 'B', 'C'])
idx2 = pd.Index(['B', 'C', 'D'])
print(idx1)
print(idx2)
# Out:
# Index(['A', 'B', 'C'], dtype='object')
# Index(['B', 'C', 'D'], dtype='object')

# %%
# 코드 14-38. append로 두 인덱스 클래스 연결하기
idx1.append(idx2)
# Out:
# Index(['A', 'B', 'C', 'B', 'C', 'D'], dtype='object')

# %%
# 코드 14-39. append로 idx1에 'D'와 'E' 추가하기
idx1.append(pd.Index(['D', 'E']))
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
# 코드 14-40. insert로 idx1에 로케이션이 1인 위치에 'D' 추가하기
idx1.insert(1, 'D')
# Out:
# Index(['A', 'D', 'B', 'C'], dtype='object')

# %%
# 코드 14-41. drop으로 idx1에서 'A' 삭제하기
idx1.drop('A')
# Out:
# Index(['B', 'C'], dtype='object')

# %%
# 열의 위치 옮기기 실습을 위해 코드 14-1의 df 다시 실행
import pandas as pd
data = [[1, 1, 8], [6, 9, 8], [2, 8, 7], [6, 9, 1]]
df = pd.DataFrame(data, columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  1  1  8
# 1  6  9  8
# 2  2  8  7
# 3  6  9  1

# %%
# 코드 14-42. df에서 C열을 가장 왼쪽으로 옮기기
cols = df.columns.drop('C').insert(0, 'C')
df[cols]
# Out:
#    C  A  B
# 0  8  1  1
# 1  8  6  9
# 2  7  2  8
# 3  1  6  9

# %%
# 코드 14-43. repeat로 인덱스 클래스의 각 원소 반복하기
print(idx1.repeat(2))
idx1.repeat([1, 2, 3])
# Out:
# Index(['A', 'A', 'B', 'B', 'C', 'C'], dtype='object')
# Index(['A', 'B', 'B', 'C', 'C', 'C'], dtype='object')

# %%
# 코드 14-44. idx1과 idx2의 합집합
print(idx1)
print(idx2)
idx1.union(idx2)
# Out:
# Index(['A', 'B', 'C'], dtype='object')
# Index(['B', 'C', 'D'], dtype='object')
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# 코드 14-45. idx1과 idx2의 교집합
idx1.intersection(idx2)
# Out:
# Index(['B', 'C'], dtype='object')

# %%
# 코드 14-46. idx1에서 idx2를 제외한 차집합
idx1.difference(idx2)
# Out:
# Index(['A'], dtype='object')

# %% [markdown]
# ### 14.4. 멀티 인덱스

# %% [markdown]
# #### 14.4.1. 멀티 인덱스의 생성

# %%
# 코드 14-47. 멀티 인덱스 생성
idx = pd.MultiIndex(levels=[['A', 'B'], ['C', 'D']],
                    codes=[[0, 0, 1, 1], [0, 1, 0, 1]],
                    names=['lev_0', 'lev_1'])
idx
# Out:
# MultiIndex([('A', 'C'),
#             ('A', 'D'),
#             ('B', 'C'),
#             ('B', 'D')],
#            names=['lev_0', 'lev_1'])

# %%
# 코드 14-48. 멀티 인덱스로 시리즈 생성
s = pd.Series([1, 2, 3, 4], index=idx)
s
# Out:
# lev_0  lev_1
# A      C        1
#        D        2
# B      C        3
#        D        4
# dtype: int64

# %%
# 코드 14-49. from_product: 곱집합을 만들어 멀티 인덱스 생성
pd.MultiIndex.from_product([['A', 'B'], ['C', 'D']], names=['lev_0', 'lev_1'])
# Out:
# MultiIndex([('A', 'C'),
#             ('A', 'D'),
#             ('B', 'C'),
#             ('B', 'D')],
#            names=['lev_0', 'lev_1'])

# %%
# 코드 14-50. from_tuples: 튜플로 멀티 인덱스 생성
tuple1 = [('A', 'C'), ('A', 'D'), ('B', 'C'), ('B', 'D')]
pd.MultiIndex.from_tuples(tuple1, names=['lev_0', 'lev_1'])
# Out:
# MultiIndex([('A', 'C'),
#             ('A', 'D'),
#             ('B', 'C'),
#             ('B', 'D')],
#            names=['lev_0', 'lev_1'])

# %%
# 코드 14-51. from_frame: 데이터 프레임을 멀티 인덱스로 변환
data = {'lev_0': ['A', 'A', 'B', 'B'],
        'lev_1': ['C', 'D', 'C', 'D']}
df = pd.DataFrame(data)
pd.MultiIndex.from_frame(df)
# Out:
# MultiIndex([('A', 'C'),
#             ('A', 'D'),
#             ('B', 'C'),
#             ('B', 'D')],
#            names=['lev_0', 'lev_1'])

# %%
# 코드 14-52. 파일에서 데이터 프레임을 불러올 때 멀티 인덱스 지정하기
url1 = 'https://github.com/panda-kim/book1/blob/main/24multiidx.xlsx?raw=true'
pd.read_excel(url1, header=[0, 1, 2], index_col=[0, 1])
# Out:
#       2024년
#         전반기         후반기
#          1차  2차  3차  1차  2차  3차
# A반 국어    60  63  63  69  79  81
#    영어    83  84  77  85  73  68
# B반 국어    89  79  79  99  92  61
#    영어    60  60  96  98  77  75

# %% [markdown]
# #### 14.4.2. 멀티 인덱스를 보유한 데이터 프레임의 인덱싱

# %%
# 코드 14-53. 멀티 인덱스를 보유한 데이터 프레임의 인덱싱 실습 예제 코드
import pandas as pd
import numpy as np
# 멀티 인덱스 생성
idx1 = pd.MultiIndex.from_product([['A반', 'B반'], ['국어', '영어']])
cols1 = pd.MultiIndex.from_product(
    [['2024년', '2025년'], ['전반기', '후반기'], ['1차', '2차', '3차', '4차']]
)

# 무작위로 4×16의 어레이를 생성해 데이터 프레임 생성
np.random.seed(0) # 난수 고정
data = np.random.randint(60, 100, (4, 16))
df = pd.DataFrame(data, index=idx1, columns=cols1)
df
# Out:
#       2024년                  ... 2025년
#         전반기             후반기  ...   전반기 후반기
#          1차  2차  3차  4차  1차  ...    4차  1차  2차  3차  4차
# A반 국어    60  63  63  99  69  ...    84  72  61  98  99
#    영어    83  84  77  97  85  ...    75  60  78  95  84
# B반 국어    89  79  79  74  99  ...    83  95  71  88  94
#    영어    60  60  96  65  98  ...    99  95  98  71  78
#
# [4 rows x 16 columns]

# %%
# 코드 14-54. 멀티 인덱스의 인덱싱은 튜플을 입력한다.
df[('2024년', '전반기', '1차')]
# Out:
# A반  국어    60
#     영어    83
# B반  국어    89
#     영어    60
# Name: (2024년, 전반기, 1차), dtype: int64

# %%
# 코드 14-55. 최상위 레벨만 입력해도 하위 레벨을 모두 가져온다.
df['2024년']
# Out:
#       전반기             후반기
#        1차  2차  3차  4차  1차  2차  3차  4차
# A반 국어  60  63  63  99  69  79  81  96
#    영어  83  84  77  97  85  73  68  69
# B반 국어  89  79  79  74  99  92  61  69
#    영어  60  60  96  65  98  77  75  64

# %%
# 코드 14-56. iloc 인덱서로 첫 번째, 세 번째, 네 번째 열 인덱싱
df.iloc[:, [0, 2, 3]]
# Out:
#       2024년
#         전반기
#          1차  3차  4차
# A반 국어    60  63  99
#    영어    83  77  97
# B반 국어    89  79  74
#    영어    60  96  65

# %%
# 코드 14-57. loc 인덱서와 slice 함수로 인덱싱
df.loc[('A반', ['국어', '영어']), ('2024년', slice(None), slice('1차', '3차'))]
# Out:
#       2024년
#         전반기         후반기
#          1차  2차  3차  1차  2차  3차
# A반 국어    60  63  63  69  79  81
#    영어    83  84  77  85  73  68

# %%
# 코드 14-58. loc 인덱서와 IndexSlice 객체로 인덱싱
ids = pd.IndexSlice
df.loc[ids['A반', ['국어', '영어']], ids['2024년', :, '1차': '3차']]
# Out:
#       2024년
#         전반기         후반기
#          1차  2차  3차  1차  2차  3차
# A반 국어    60  63  63  69  79  81
#    영어    83  84  77  85  73  68

# %%
# 코드 14-59. 후반기 1차, 2차, 3차 시험의 각 반의 통합 평균 구하기(slice)
(df.loc[:, (slice(None), '후반기', slice('1차', '3차'))]
 .groupby(level=0).mean()
)
# Out:
#    2024년             2025년
#      후반기               후반기
#       1차    2차    3차    1차    2차    3차
# A반  77.0  76.0  74.5  66.0  69.5  96.5
# B반  98.5  84.5  68.0  95.0  84.5  79.5

# %%
# 코드 14-60. 후반기 1차, 2차, 3차 시험의 각 반의 통합 평균 구하기(IndexSlice)
ids = pd.IndexSlice
(df.loc[:, ids[:, '후반기', '1차': '3차']]
 .groupby(level=0).mean()
)
# Out:
#    2024년             2025년
#      후반기               후반기
#       1차    2차    3차    1차    2차    3차
# A반  77.0  76.0  74.5  66.0  69.5  96.5
# B반  98.5  84.5  68.0  95.0  84.5  79.5

# %%
# 코드 14-61. xs 함수로 전반기 성적만 추출하기
df.xs('전반기', axis=1, level=1)
# Out:
#       2024년             2025년
#          1차  2차  3차  4차    1차  2차  3차  4차
# A반 국어    60  63  63  99    83  66  84  84
#    영어    83  84  77  97    80  76  65  75
# B반 국어    89  79  79  74    92  91  70  83
#    영어    60  60  96  65    91  61  61  99

# %% [markdown]
# #### 14.4.3. 멀티 인덱스를 다루는 함수들

# %%
# 코드 14-62. 멀티 인덱스를 다루는 함수들 실습 예제 코드
import pandas as pd
import numpy as np
# 멀티 인덱스 생성
cols1 = pd.MultiIndex.from_product([['전반기', '후반기'], ['1차', '2차']])

# 무작위로 5×4의 어레이를 생성해 데이터 프레임 생성
np.random.seed(2) # 난수 고정
data = np.random.randint(60, 100, (5, 4))
df = pd.DataFrame(data, columns=cols1)
df
# Out:
#   전반기     후반기
#    1차  2차  1차  2차
# 0  75  68  82  78
# 1  71  67  94  91
# 2  71  81  91  86
# 3  80  97  99  63
# 4  98  64  99  98

# %%
# 코드 14-63. 컬럼즈의 멀티 인덱스 중에 첫 번째 레벨 삭제하기
df.droplevel(0, axis=1)
# Out:
#    1차  2차  1차  2차
# 0  75  68  82  78
# 1  71  67  94  91
# 2  71  81  91  86
# 3  80  97  99  63
# 4  98  64  99  98

# %%
# 코드 14-64. 컬럼즈의 첫 번째 레벨과 두 번째 레벨의 맞교환
df.swaplevel(0, 1, axis=1).sort_index(axis=1)
# Out:
#    1차      2차
#   전반기 후반기 전반기 후반기
# 0  75  82  68  78
# 1  71  94  67  91
# 2  71  91  81  86
# 3  80  99  97  63
# 4  98  99  64  98

# %%
# 코드 14-65. 컬럼즈의 두 번째 레벨만 추출
df.columns.get_level_values(1)
# Out:
# Index(['1차', '2차', '1차', '2차'], dtype='object')

# %%
# 코드 14-66. 컬럼즈의 레벨 수 확인하기
df.columns.nlevels
# Out:
# 2

# %%
# 코드 14-67. 두 번째 레벨에서 2차 열 삭제하기
df.drop('2차', axis=1, level=1)
# Out:
#   전반기 후반기
#    1차  1차
# 0  75  82
# 1  71  94
# 2  71  91
# 3  80  99
# 4  98  99

# %%
# 코드 14-68. 두 번째 레벨이 1차인 열만 100 더하기
s = pd.Series([100, 0], index=['1차', '2차'])
df.add(s, level=1)
# Out:
#    전반기      후반기
#     1차  2차   1차  2차
# 0  175  68  182  78
# 1  171  67  194  91
# 2  171  81  191  86
# 3  180  97  199  63
# 4  198  64  199  98

# %%
# 코드 14-69. 컬럼즈에 세 번째 레벨 추가하기
lv2 = ['첫 번째', '두 번째', '세 번째', '네 번째']
df.set_axis(
    [df.columns.get_level_values(0), df.columns.get_level_values(1), lv2],
    axis=1
)
# Out:
#    전반기       후반기
#     1차   2차   1차   2차
#   첫 번째 두 번째 세 번째 네 번째
# 0   75   68   82   78
# 1   71   67   94   91
# 2   71   81   91   86
# 3   80   97   99   63
# 4   98   64   99   98

# %%
# 코드 14-70. to_frame 함수로 데이터 프레임으로 변환 후 세 번째 레벨 추가하기

# 컬럼즈를 데이터 프레임으로 변환하고 lv2 열을 생성하고 df1으로 지정
df1 = df.columns.to_frame().assign(lv2=lv2)

# df1을 from_frame 메서드로 멀티 인덱스로 변환해 변수 col2로 지정
col2 = pd.MultiIndex.from_frame(df1, names=[None, None, None])

# col2를 df의 컬럼즈로 지정
df.set_axis(col2, axis=1)
# Out:
#    전반기       후반기
#     1차   2차   1차   2차
#   첫 번째 두 번째 세 번째 네 번째
# 0   75   68   82   78
# 1   71   67   94   91
# 2   71   81   91   86
# 3   80   97   99   63
# 4   98   64   99   98

# %% [markdown]
# #### 14.4.4. 구간 인덱스

# %%
# 코드 14-71. 인터벌 객체로 구간 인덱스 생성하기
idx1 = pd.IntervalIndex([pd.Interval(1, 3), pd.Interval(3, 5)])
idx1
# Out:
# IntervalIndex([(1, 3], (3, 5]], dtype='interval[int64, right]')

# %%
# 코드 14-72. 구간 인덱스를 사용한 인덱싱
s1 = pd.Series(['가', '나'], index=idx1)
s1.loc[[2, 5, 3]]
# Out:
# (1, 3]    가
# (3, 5]    나
# (1, 3]    가
# dtype: object

# %%
# 코드 14-73. 구간 인덱스를 생성할 데이터 프레임 생성
data1 = {'min': [80, 60, 40, 0],
         'max': [100, 79, 59, 39],
         'grade': ['A', 'B', 'C', 'D']}
data2 = {'이름': ['김판다', '강승주', '조민영'],
         '점수': [77, 58, 92]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
df1
# Out:
#    min  max grade
# 0   80  100     A
# 1   60   79     B
# 2   40   59     C
# 3    0   39     D

# %%
# 코드 14-74. 데이터 프레임으로 구간 인덱스 생성하기
idx2 = pd.IntervalIndex.from_arrays(df1['min'], df1['max'], closed='both')
idx2
# Out:
# IntervalIndex([[80, 100], [60, 79], [40, 59], [0, 39]], dtype='interval[int64, both]')

# %%
# 코드 14-75. 구간 인덱스를 활용해 df2에 학점 열 생성하기
s2 = df1['grade'].set_axis(idx2)
df2.assign(학점=s2.loc[df2['점수']].values)
# Out:
#     이름  점수 학점
# 0  김판다  77  B
# 1  강승주  58  C
# 2  조민영  92  A
